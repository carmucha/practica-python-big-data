# %%
import pandas as pd

# %% [markdown]
# Cargar datos

# %%
# Importamos el dataset de los datos de los pokemon
df = pd.read_csv('dataset_final.csv')
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
'''
1. ¿Cuántos pokémon hay en el dataset? --> 800
'''
df['Name'].count()
# Out:
# 800

# %%
'''
2. ¿Cuántos pokémon hay de tipo Poison? (Type 1) --> 28
'''

df_poison = df[df['Type 1'] == "Poison"]
df_poison['Name'].count()
# Out:
# 28

# %%
'''
3. ¿Cuántos tipos diferentes de pokémon hay? (Type 1)
'''
df.groupby('Type 1')['Name'].count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Name, dtype: int64

# %%
'''
2. ¿Cuántos pokémon hay de cada tipo? (Type 1)
'''
df.groupby('Type 1')['Name'].count()
'''
2.1 ¿cual es el tipo de pokémon con más pokémon? (Type 1)
'''
df.groupby('Type 1')['Name'].count().sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Name, dtype: int64

# %%
'''
3. ¿Cuál es el pokémon más rápido? --> DeoxysSpeed Forme
'''

df.sort_values(['Speed'], ascending=False)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 428  386         DeoxysNormal Forme  Psychic     NaN    600   50     150
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# ..   ...                        ...      ...     ...    ...  ...     ...
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 230  213                    Shuckle      Bug    Rock    505   20      10
# 495  446                   Munchlax   Normal     NaN    390  135      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       90       95       90    180           3       True
# 315       45       50       50    160           3      False
# 428       50      150       50    150           3       True
# 154       85       70       95    150           1      False
# 71        65      175       95    150           1      False
# ..       ...      ...      ...    ...         ...        ...
# 658       91       24       86     10           5      False
# 486       95       10       45     10           4      False
# 359       45       45       45     10           3      False
# 230      230       10      230      5           2      False
# 495       40       40       85      5           4      False
#
# [800 rows x 13 columns]

# %%
'''
4. ¿Cuántos pokemon tiene una defensa superior a 100?
'''
'''
4.1 ¿Cuántos pokemon tiene una defensa superior a 100? -> 123
'''
d_mayor_100 = df[df['Defense'] > 100]

#df[d_mayor_100].count()

d_mayor_100['Name'].count()
# Out:
# 123

# %%
'''
5. ¿Cuántos pokemon tiene una defensa superior a 100 y una velocidad superior a 100? --> 9
'''

df_speed_defense = df[(df['Defense'] > 100) & (df['Speed'] > 100)]

df_speed_defense['Name'].count()
# Out:
# 9

# %%
'''
6. Ordena el dataset por el tipo 1 y por el tipo 2
'''
df.sort_values(['Type 1', 'Type 2'], ascending=[True, False])
# Out:
#        #                 Name Type 1 Type 2  Total   HP  Attack  Defense  \
# 307  283              Surskit    Bug  Water    269   40      30       32
# 220  205           Forretress    Bug  Steel    465   75      90      140
# 228  212               Scizor    Bug  Steel    500   70     130      100
# 229  212    ScizorMega Scizor    Bug  Steel    600   70     150      140
# 460  413  WormadamTrash Cloak    Bug  Steel    424   60      69       95
# ..   ...                  ...    ...    ...    ...  ...     ...      ...
# 655  594            Alomomola  Water    NaN    470  165      75       80
# 724  656              Froakie  Water    NaN    314   41      56       40
# 725  657            Frogadier  Water    NaN    405   54      63       52
# 762  692            Clauncher  Water    NaN    330   50      53       62
# 763  693            Clawitzer  Water    NaN    500   71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 307       50       52     65           3      False
# 220       60       60     40           2      False
# 228       55       80     65           2      False
# 229       65      100     75           2      False
# 460       69       95     36           4      False
# ..       ...      ...    ...         ...        ...
# 655       40       45     65           5      False
# 724       62       44     71           6      False
# 725       83       56     97           6      False
# 762       58       63     44           6      False
# 763      120       89     59           6      False
#
# [800 rows x 13 columns]

# %%
'''
7. Crea un nuevo dataset con los pokémon de tipo Water y Fire como primer tipo
'''
poke_water_fire = df[(df['Type 1'] == 'Fire') | (df['Type 1'] == 'Water')]
poke_water_fire
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 762  692                  Clauncher  Water     NaN    330  50      53
# 763  693                  Clawitzer  Water     NaN    500  71      73
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# 5         58       80       65     80           1      False
# 6         78      109       85    100           1      False
# 7        111      130       85    100           1      False
# 8         78      159      115    100           1      False
# ..       ...      ...      ...    ...         ...        ...
# 735       58       73       54     72           6      False
# 736       72      109       66    106           6      False
# 762       62       58       63     44           6      False
# 763       88      120       89     59           6      False
# 799      120      130       90     70           6       True
#
# [164 rows x 13 columns]

# %%
'''
8. Crea un nuevo dataset con los pokemon Legendary
'''
poke_legendary = df[(df['Legendary'] == True)]
poke_legendary
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [65 rows x 13 columns]

# %%
'''
9. Calcula el promedio de stats de los pokemon Legendary (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed) y los no Legendary
'''
poke_legendary.mean(axis=0)
poke_not_legendary = df[(df['Legendary'] == False)]
poke_not_legendary.mean(axis=0)
# Out:
# C:\Users\c_san\AppData\Local\Temp\ipykernel_400\2881248998.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   poke_legendary.mean(axis=0)
# C:\Users\c_san\AppData\Local\Temp\ipykernel_400\2881248998.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   poke_not_legendary.mean(axis=0)
# #             353.315646
# Total         417.213605
# HP             67.182313
# Attack         75.669388
# Defense        71.559184
# Sp. Atk        68.454422
# Sp. Def        68.892517
# Speed          65.455782
# Generation      3.284354
# Legendary       0.000000
# dtype: float64

# %%
'''
10. Crea un nuevo dataframe con el resultado del anterior ejercicio comparando ambos promedios

ejemplo:
                HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
Legendary       99      90       89       91       94     90
No Legendary    80      95       75       12       43     87

'''

df_pokemon = pd.DataFrame(df[poke_legendary & poke_not_legendary],columns=poke_legendary.columns(), index=['Legendary', 'No Legendary'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     300         #  (xint or xbool) and (yint or bool)
# --> 301         result = op(x, y)
#     302     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_400\59604882.py in <module>
#       9 '''
#      10
# ---> 11 df_pokemon = pd.DataFrame(df[poke_legendary & poke_not_legendary],columns=poke_legendary.columns(), index=['Legendary', 'No Legendary'])
#      12
#      13
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      68     @unpack_zerodim_and_defer("__and__")
#      69     def __and__(self, other):
# ---> 70         return self._logical_method(other, operator.and_)
#      71
#      72     @unpack_zerodim_and_defer("__rand__")
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    6953         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6954
# -> 6955         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6956         return self._construct_result(new_data)
#    6957
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6992             # TODO operate_blockwise expects a manager of the same type
#    6993             with np.errstate(all="ignore"):
# -> 6994                 bm = self._mgr.operate_blockwise(
#    6995                     # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6996                     # incompatible type "Union[ArrayManager, BlockManager]"; expected
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#    1417         Apply array_op blockwise with another (aligned) BlockManager.
#    1418         """
# -> 1419         return operate_blockwise(self, other, array_op)
#    1420
#    1421     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      61     res_blks: list[Block] = []
#      62     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 63         res_values = array_op(lvals, rvals)
#      64         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65             res_values = res_values.reshape(1, -1)
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     389         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     390
# --> 391         res_values = na_logical_op(lvalues, rvalues, op)
#     392         # error: Cannot call function of unknown type
#     393         res_values = filler(res_values)  # type: ignore[operator]
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     306             x = ensure_object(x)
#     307             y = ensure_object(y)
# --> 308             result = libops.vec_binop(x.ravel(), y.ravel(), op)
#     309         else:
#     310             # let null fall thru
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.vec_binop()
#
# c:\Users\c_san\anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'

# %%
'''
11. Añade una nueva colunma ['Doble tipo'] al dataframe inicial que inndique si el pokemo tiene dos tipos o no
'''

# %%
'''
12. Muestra las columas Name, Type 1, Type 2 de los pokémon que tienen dos tipos y ordenalos por Type 1 , Type 2 y Name
'''

# %%
from functools import reduce, partial

'''
13. Dada una lista de Artículos con sus precio. Define las siguientes funciones:
Puedes definir más funciones si lo consideras necesario.
'''
articulos = {
    'Camisa': 20,
    'Pantalón': 30,
    'Calcetines': 5,
    'Zapatos': 50,
    'Gorra': 10,
    'Bufanda': 15,
    'Gafas': 25,
    'Reloj': 35,
    'Corbata': 40,
}

compra = ['Camisa', 'Pantalón', 'Pantalón', 'Gorra', 'Gafas', 'Corbata']


# A. Una función que calcule el precio total de la compra
def precio_total(compra, articulos):
    precio_compra = reduce(lambda acc, item: articulos[item] + acc,  compra, 0)
    return precio_compra

print('Precio Compra: ', precio_total(compra, articulos))


# B. Una función que calcule el precio total de la compra con un descuento del 10%

def precio_con_descuento(porcetaje_descuento, precio):
    descuento = precio * porcetaje_descuento/100
    return precio - descuento

descuento_10_porciento = partial(precio_con_descuento, 10)

print("Descuento del 10%: ", descuento_10_porciento(precio_total(compra, articulos)))


# C. Una función que calcule el precio total de la compra con un descuento del 10% si la compra supera los 100€

def descuento_compra_mayor_100(total):
    if total > 100:
        result = descuento_10_porciento(total)
    else:
        result = total
    return result

print('Descuento compra mayor de 100: ', descuento_compra_mayor_100(precio_total(compra, articulos)))


# D. Una función que calcule el precio total aplicando el IVA (21%)

add_impuesto = lambda impuesto, cantidad: (cantidad * impuesto/100) + cantidad

add_iva_21 = partial(add_impuesto, 21)

calcula_total_mas_iva = add_iva_21(precio_total(compra, articulos))

print('Precio con IVA: ', calcula_total_mas_iva)

# E.lista los artículos cuyo precio es superior a 20€

menor_20 = list(filter(lambda item: articulos[item] > 20, compra))
print('Productos con precio menor de 20: ', menor_20)
# Out:
# Precio Compra:  155
# Descuento del 10%:  139.5
# Descuento compra mayor de 100:  139.5
# Precio con IVA:  187.55
# Productos con precio menor de 20:  ['Pantalón', 'Pantalón', 'Gafas', 'Corbata']

# %%
'''
14. Dada una lista de tuplas con el nombre de un alumno, apellidos, curso y sus notas. 

 Define una funcion que reciba el curso y saque una lista en la que aparezca e nombre y apellidos y el promedio de sus notas.
 Puedes definir más funciones si lo consideras necesario.
'''

alumnos = [('Juan', 'Pérez', '1', [5, 6, 7, 8, 9]),
            ('Ana', 'García', '2', [5, 6, 7, 8, 9]),
            ('Luis', 'González', '1', [5, 6, 7, 8, 9]),
            ('María', 'Martínez', '2', [5, 6, 7, 8, 9]),
            ('Pedro', 'Rodríguez', '1', [5, 6, 7, 8, 9]),
            ('Lucía', 'Hernández', '2', [5, 6, 7, 8, 9]),
            ('Marta', 'López', '1', [5, 6, 7, 8, 9]),
            ('Sara', 'Díaz', '2', [5, 6, 7, 8, 9]),
            ('Javier', 'Sánchez', '1', [5, 6, 7, 8, 9]),
            ('Miguel', 'Fernández', '2', [5, 6, 7, 8, 9]),
            ('Sergio', 'Jiménez', '1', [5, 6, 7, 8, 9]),
            ('Sandra', 'Ruiz', '2', [5, 6, 7, 8, 9]),
            ('Pablo', 'Álvarez', '1', [5, 6, 7, 8, 9]),
            ('María', 'Gómez', '2', [5, 6, 7, 8, 9]),
]

# %%
def notas_por_curso(curso):
    alumnos_por_curso = list(filter(lambda alumno: alumno[2] == curso, alumnos))
    return list(map(lambda alumno: (alumno[0], alumno[1], promedio_notas(alumno[3])), alumnos_por_curso))
   

def promedio_notas(notas):
    suma_notas = reduce(lambda accum, nota: accum + nota, notas, 0)
    return suma_notas / len(notas)

# %%
notas_por_curso('1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 notas_por_curso('1')
#
# Cell In [14], line 3, in notas_por_curso(curso)
#       1 def notas_por_curso(curso):
#       2     alumnos_por_curso = list(filter(lambda alumno: alumno[2] == curso, alumnos))
# ----> 3     return list(map(lambda alumno: (alumno[0], alumno[1], promedio_notas(alumno[3])), alumnos_por_curso))
#
# Cell In [14], line 3, in notas_por_curso.<locals>.<lambda>(alumno)
#       1 def notas_por_curso(curso):
#       2     alumnos_por_curso = list(filter(lambda alumno: alumno[2] == curso, alumnos))
# ----> 3     return list(map(lambda alumno: (alumno[0], alumno[1], promedio_notas(alumno[3])), alumnos_por_curso))
#
# Cell In [14], line 7, in promedio_notas(notas)
#       6 def promedio_notas(notas):
# ----> 7     suma_notas = reduce(lambda accum, nota: accum + nota, notas, 0)
#       8     return suma_notas / len(notas)
#
# NameError: name 'reduce' is not defined
